# %%
# !python generate.py \
  --imu_flow_ckpt /home/qsw26/smartfall/MGFM/stage5_model/imu_flow_best.pt \
  --skeleton_folder /home/qsw26/smartfall/SmartFallMM-Dataset/young/skeleton \
  --phone_accel_folder /home/qsw26/smartfall/motion_gen_attention_angular/young/accelerometer/phone/ \
  --watch_accel_folder /home/qsw26/smartfall/motion_gen_attention_angular/young/accelerometer/watch/ \
  --batch_size 16 \
  --window 32 \
  --stride 16 \
  --imu_encoder_type cnn \
  --ode_steps 50 \
  --cfg_scale 3.0 \
  --save_gif \
    --temporal_block_type attention \
  --per_activity_target 100 \
  --max_batches 500 \
  --output_dir outputs/stage5_cnn_contrast_attention_pool_frameang_for_test
